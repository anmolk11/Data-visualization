# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
import numpy as np
import random

style.use("seaborn") # for grid background

# %%
df = pd.read_csv("HRDataset_v14.csv")
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# 0  Michael Albert       22.0          LinkedIn          Exceeds
# 1      Simon Roup        4.0            Indeed      Fully Meets
# 2  Kissy Sullivan       20.0          LinkedIn      Fully Meets
# 3    Elijiah Gray       16.0            Indeed      Fully Meets
# 4  Webster Butler       39.0     Google Search      Fully Meets
#
#    EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0              4.60               5                    0
# 1              4.96               3                    6
# 2              3.02               3                    0
# 3              4.84               5                    0
# 4              5.00               4                    0
#
#   LastPerformanceReview_Date DaysLateLast30 Absences
# 0                  1/17/2019              0        1
# 1                  2/24/2016              0       17
# 2                  5/15/2012              0        3
# 3                   1/3/2019              0       15
# 4                   2/1/2016              0        2
#
# [5 rows x 36 columns]

# %%
df.shape
# Out:
# (311, 36)

# %% [markdown]
# # Line plot

# %%
import random
x = [i for i in range(1,11)]
y1 = [random.randint(1,100) for i in range(1,11)]
y2 = [random.randint(1,100) for i in range(1,11)]
# plt.plot(x,y,color = 'r',marker = '^',linestyle = '--',linewidth = '2',markersize = 10)
plt.plot(x,y1,"r^--",linewidth = '2',markersize = 10,label = 'Red')
plt.plot(x,y2,"b.-",linewidth = '2',markersize = 10,label = 'Blue')
#same result as above line
plt.axis([1,10,1,100]) # [xmin,xmax,ymin,ymax]
plt.title("Random plot",fontsize = 15)
plt.xlabel("Points")
plt.ylabel("Random int")
plt.legend(loc = 4)

plt.show()

# %% [markdown]
# # Histogram

# %%
plt.figure(figsize = (5,4))
x1 = np.random.randint(18,45,(100))
x2 = np.random.randint(18,45,(100))
bins = [x for x in range(18,45,5)]
plt.hist([x1,x2],color = ['r','b'],bins = bins,rwidth = 0.8,histtype = "bar",label = ["Red","Blue"])
#rwidth for spacing btw the bars
#bins for number of data items that one bar covers
plt.legend()
plt.show()

# %% [markdown]
# # Bar chart

# %%
x = ['A','B','C','D','E']
c1 = np.random.randint(20,50,(5))
c2 = np.random.randint(20,50,(5))
c3 = np.random.randint(20,50,(5))

plt.bar(x,c1)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(x,c1)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize = (10,6))
plt.bar(x,c1,color = 'r',edgecolor = 'k',linewidth = 3,alpha = 0.2,label = "C1")
#alpha makes the color kind of transparent
plt.legend()
plt.show()

# %%
index = np.arange(len(x))
width = 0.3

plt.figure(figsize = (10,6))
plt.xticks(index + width,x)
plt.bar(index,c1,color = 'r',alpha = 0.5,label = "A",width = width)
plt.bar(index + width,c2,color = 'b',alpha = 0.5,label = "B",width = width)
plt.bar(index + 2 * width,c3,color = 'g',alpha = 0.5,label = "C",width = width)
plt.legend()

# %%
index = np.arange(len(x))
width = 0.3

plt.figure(figsize = (10,6))
plt.yticks(index + width,x)
plt.barh(index,c1,width,color = 'r',alpha = 0.5,label = "A")
plt.barh(index + width,c2,width,color = 'b',alpha = 0.5,label = "B")
plt.barh(index + 2 * width,c3,width,color = 'g',alpha = 0.5,label = "C")
plt.legend()

# %% [markdown]
# # Scatter Plot

# %%
x = df["EngagementSurvey"]
y = df["EmpSatisfaction"]

plt.figure(figsize = (16,9))
plt.scatter(x,y)
plt.xlabel("Engagement")
plt.ylabel("Satisfaction")
plt.show()

# %%
x = df["EngagementSurvey"]
y = df["EmpSatisfaction"]

plt.figure(figsize = (16,9))
plt.scatter(x,y,marker = 'o',s = 100,alpha = 0.5,edgecolor = 'k',linewidth = 1)
plt.xlabel("Engagement")
plt.ylabel("Satisfaction")
plt.show()

# %%
x = df["EngagementSurvey"]
y = df["EmpSatisfaction"]

plt.figure(figsize = (16,9))
plt.scatter(x,y,marker = 'o',s = 100,alpha = 0.5,edgecolor = 'k',linewidth = 1)
plt.xlabel("Engagement")
plt.ylabel("Satisfaction")
plt.show()

# %%
x = df["EngagementSurvey"]
y = df["EmpSatisfaction"]

plt.figure(figsize = (16,9))

colors = np.random.randint(1,10,(len(df["EngagementSurvey"])))

plt.scatter(x,y,marker = 'o',s = 100,alpha = 0.5,c = colors,edgecolor = 'k',linewidth = 1)
plt.xlabel("Engagement")
plt.ylabel("Satisfaction")
plt.show()

# %%
x = df["EngagementSurvey"]
y = df["EmpSatisfaction"]

plt.figure(figsize = (16,9))

colors = np.random.randint(1,10,(len(df["EngagementSurvey"])))

plt.scatter(x,y,marker = 'o',s = 100,alpha = 0.5,c = colors,cmap = "Blues",edgecolor = 'k',linewidth = 1)

cbar = plt.colorbar()
cbar.set_label("1 to 10")

plt.xlabel("Engagement")
plt.ylabel("Satisfaction")
plt.show()

# %%
x = df["EngagementSurvey"][:100]
y = df["EmpSatisfaction"][:100]

sizes = np.random.randint(1,300,(len(x)))

plt.figure(figsize = (16,9))
plt.scatter(x,y,marker = 'o',s = sizes,alpha = 0.5,edgecolor = 'k',linewidth = 1)
plt.xlabel("Engagement")
plt.ylabel("Satisfaction")
plt.show()

# %%
src = df["RecruitmentSource"].unique()
dix = {src[c]:c for c in range(len(src))}
colors = [dix[x] for x in df["RecruitmentSource"]]

print(src)

x = df["EngagementSurvey"][:100]
y = df["EmpSatisfaction"][:100]

sizes = np.random.randint(1,300,(len(x)))

plt.figure(figsize = (16,9))
plt.scatter(x,y,marker = 'o',c = colors[:100],cmap = "summer",alpha = 0.5,edgecolor = 'k',linewidth = 1)
plt.xlabel("Engagement")
plt.ylabel("Satisfaction")

cbar = plt.colorbar()

plt.show()
# Out:
# ['LinkedIn' 'Indeed' 'Google Search' 'Employee Referral'
#  'Diversity Job Fair' 'On-line Web application' 'CareerBuilder' 'Website'
#  'Other']

# %% [markdown]
# # Pie chart

# %%
#Emp from each src
d = df.groupby("RecruitmentSource").size().sort_values(ascending = False)
ind = d.index.tolist()
freq = [d[src] for src in ind]
plt.figure(figsize = (16,8))
plt.pie(freq,labels = ind)
plt.show()

# %%
#Using explode

explode = [0] * len(ind)

explode[4] = 0.1

plt.figure(figsize = (16,8))
plt.pie(freq,labels = ind,explode = explode)
plt.show()

# %%
plt.figure(figsize = (16,8))
plt.pie(freq,labels = ind,autopct = "%0.1f%%",shadow = True)
plt.show()

# %%
wedgeprops = {"linewidth" : 1,"width" : 0.8,"edgecolor" : "k"} #width makes a donought
textprops = {"fontsize" : 15,"color" : "b"}
plt.figure(figsize = (20,12))
plt.pie(freq,autopct = "%0.1f%%",shadow = True,frame = True,
        textprops = textprops,wedgeprops = wedgeprops,counterclock=False)
plt.legend(ind,loc = 4)
plt.show()

# %% [markdown]
# # Subplots
# Making multiple plots in limited space

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (16,9))

plt.subplot(3,2,1)
plt.pie([1])

plt.subplot(3,2,2)
plt.pie([1,2])

plt.subplot(3,2,3)
plt.pie([1,2,3])

plt.subplot(3,2,4)
plt.pie([1,2,3,4])

plt.subplot(3,2,5)
plt.pie([1,2,3,4,5])

plt.subplot(3,2,6)
plt.pie([1,2,3,4,5,6])

plt.show()

# %%
plt.figure(figsize = (16,9))

plt.subplot(3,2,1)
#----------------------------------------- line plot - 1 ------------------------------------------------------
x = [i for i in range(1,11)]
y1 = [random.randint(1,100) for i in range(1,11)]
y2 = [random.randint(1,100) for i in range(1,11)]
# plt.plot(x,y,color = 'r',marker = '^',linestyle = '--',linewidth = '2',markersize = 10)
plt.plot(x,y1,"r^--",linewidth = '2',markersize = 10,label = 'Red')
plt.plot(x,y2,"b.-",linewidth = '2',markersize = 10,label = 'Blue')
#same result as above line
plt.axis([1,10,1,100]) # [xmin,xmax,ymin,ymax]
plt.title("Random plot",fontsize = 15)
plt.xlabel("Points")
plt.ylabel("Random int")
plt.legend(loc = 4)
#----------------------------------------- line plot - 1 ------------------------------------------------------
plt.subplot(3,2,2)
plt.pie([1,2])

plt.subplot(3,2,3)
plt.pie([1,2,3])

plt.subplot(3,2,4)
plt.pie([1,2,3,4])

plt.subplot(3,2,5)
plt.pie([1,2,3,4,5])

plt.subplot(3,2,6)
plt.pie([1,2,3,4,5,6])

plt.show()
